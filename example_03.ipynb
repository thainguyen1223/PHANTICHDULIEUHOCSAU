# %% [markdown]
# <a href="https://colab.research.google.com/github/quangvinht/Phan_tich_du_lieu_hoc_sau/blob/main/example_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Vấn đề 1:

# %%
patientheartrate = pd.read_csv('https://raw.githubusercontent.com/huynhhoc/phantichdulieu/main/Data/patient_heart_rate.csv')

# %%
patientheartrate.head(5)
# Out:
#      1    Mickéy Mousé    56       70kgs  72  69  71   -  -.1 -.2
# 0  2.0     Donald Duck  34.0   154.89lbs   -   -   -  85   84  76
# 1  3.0      Mini Mouse  16.0         NaN   -   -   -  65   69  72
# 2  4.0  Scrooge McDuck   NaN       78kgs  78  79  72   -    -   -
# 3  5.0    Pink Panther  54.0  198.658lbs   -   -   -  69  NaN  75
# 4  6.0     Huey McDuck  52.0      189lbs   -   -   -  68   75  72

# %%
column_names=["ID", "Name", "Age", "Weight", "m0006", "m0612","m1218", "f006", "f0612", "f1218"]
patientheartrate = pd.read_csv('https://raw.githubusercontent.com/huynhhoc/phantichdulieu/main/Data/patient_heart_rate.csv', names = column_names)

# %%
patientheartrate.head(5)
# Out:
#     ID            Name   Age      Weight m0006 m0612 m1218 f006 f0612 f1218
# 0  1.0    Mickéy Mousé  56.0       70kgs    72    69    71    -     -     -
# 1  2.0     Donald Duck  34.0   154.89lbs     -     -     -   85    84    76
# 2  3.0      Mini Mouse  16.0         NaN     -     -     -   65    69    72
# 3  4.0  Scrooge McDuck   NaN       78kgs    78    79    72    -     -     -
# 4  5.0    Pink Panther  54.0  198.658lbs     -     -     -   69   NaN    75

# %% [markdown]
# Vấn đề 2:

# %%
patientheartrate[['Firstname', 'Lastname']]=patientheartrate['Name'].str.split(expand = True)

# %%
patientheartrate.head(5)
# Out:
#     ID            Name   Age      Weight  ... f0612 f1218 Firstname Lastname
# 0  1.0    Mickéy Mousé  56.0       70kgs  ...     -     -    Mickéy    Mousé
# 1  2.0     Donald Duck  34.0   154.89lbs  ...    84    76    Donald     Duck
# 2  3.0      Mini Mouse  16.0         NaN  ...    69    72      Mini    Mouse
# 3  4.0  Scrooge McDuck   NaN       78kgs  ...     -     -   Scrooge   McDuck
# 4  5.0    Pink Panther  54.0  198.658lbs  ...   NaN    75      Pink  Panther
#
# [5 rows x 12 columns]

# %%
#Xoa cot Name
patientheartrate = patientheartrate.drop('Name',axis=1)
patientheartrate
# Out:
#       ID   Age      Weight m0006 m0612  ... f006 f0612 f1218 Firstname Lastname
# 0    1.0  56.0       70kgs    72    69  ...    -     -     -    Mickéy    Mousé
# 1    2.0  34.0   154.89lbs     -     -  ...   85    84    76    Donald     Duck
# 2    3.0  16.0         NaN     -     -  ...   65    69    72      Mini    Mouse
# 3    4.0   NaN       78kgs    78    79  ...    -     -     -   Scrooge   McDuck
# 4    5.0  54.0  198.658lbs     -     -  ...   69   NaN    75      Pink  Panther
# 5    6.0  52.0      189lbs     -     -  ...   68    75    72      Huey   McDuck
# 6    7.0  19.0       56kgs     -     -  ...   71    78    75     Dewey   McDuck
# 7    8.0  32.0       78kgs    78    76  ...    -     -     -    Scööpy      Doo
# 8    NaN   NaN         NaN   NaN   NaN  ...  NaN   NaN   NaN       NaN      NaN
# 9    NaN   NaN         NaN   NaN   NaN  ...  NaN   NaN   NaN       NaN      NaN
# 10   9.0  52.0      189lbs     -     -  ...   68    75    72      Huey   McDuck
# 11  10.0  12.0       45kgs     -     -  ...   92    95    87     Louie   McDuck
# 12  11.0   NaN       60kgs    78    75  ...    -     -     -     Henry      Nam
# 13  12.0  34.0         NaN    65    67  ...    -     -     -    Michel     Long
# 14  13.0   NaN         NaN     -     -  ...   68    72    70      Tana    Ricky
# 15  14.0   NaN         NaN   NaN   NaN  ...  NaN   NaN   NaN  UniLever     None
# 16  15.0  52.0      180lbs     -     -  ...   68    75    72       NaN      NaN
#
# [17 rows x 11 columns]

# %% [markdown]
# Vấn đề 3

# %%
weight=patientheartrate['Weight']
for i in range(len(weight)):
  x = str(weight[i])
  if "lbs" in x[-3:]:
    #remove the lbs from the value
    x = x[:-3:]
    float_x = float(x)
    y = int(float_x/2.205)
    y = str(y)+"kgs"
    weight[i] = y

# %%
patientheartrate.head(5)
# Out:
#     ID   Age Weight m0006 m0612 m1218 f006 f0612 f1218 Firstname Lastname
# 0  1.0  56.0  70kgs    72    69    71    -     -     -    Mickéy    Mousé
# 1  2.0  34.0  70kgs     -     -     -   85    84    76    Donald     Duck
# 2  3.0  16.0    NaN     -     -     -   65    69    72      Mini    Mouse
# 3  4.0   NaN  78kgs    78    79    72    -     -     -   Scrooge   McDuck
# 4  5.0  54.0  90kgs     -     -     -   69   NaN    75      Pink  Panther

# %% [markdown]
# Vấn đề 4:

# %%
import seaborn as sns

sns.heatmap(patientheartrate.isna(), yticklabels=False, cbar=True,  cmap='viridis')

# %%
patientheartrate.dropna(how="all", inplace = True)
patientheartrate
# Out:
#       ID   Age Weight m0006 m0612 m1218 f006 f0612 f1218 Firstname Lastname
# 0    1.0  56.0  70kgs    72    69    71    -     -     -    Mickéy    Mousé
# 1    2.0  34.0  70kgs     -     -     -   85    84    76    Donald     Duck
# 2    3.0  16.0    NaN     -     -     -   65    69    72      Mini    Mouse
# 3    4.0   NaN  78kgs    78    79    72    -     -     -   Scrooge   McDuck
# 4    5.0  54.0  90kgs     -     -     -   69   NaN    75      Pink  Panther
# 5    6.0  52.0  85kgs     -     -     -   68    75    72      Huey   McDuck
# 6    7.0  19.0  56kgs     -     -     -   71    78    75     Dewey   McDuck
# 7    8.0  32.0  78kgs    78    76    75    -     -     -    Scööpy      Doo
# 10   9.0  52.0  85kgs     -     -     -   68    75    72      Huey   McDuck
# 11  10.0  12.0  45kgs     -     -     -   92    95    87     Louie   McDuck
# 12  11.0   NaN  60kgs    78    75    72    -     -     -     Henry      Nam
# 13  12.0  34.0    NaN    65    67    55    -     -     -    Michel     Long
# 14  13.0   NaN    NaN     -     -     -   68    72    70      Tana    Ricky
# 15  14.0   NaN    NaN   NaN   NaN   NaN  NaN   NaN   NaN  UniLever     None
# 16  15.0  52.0  81kgs     -     -     -   68    75    72       NaN      NaN

# %%
sns.heatmap(patientheartrate.isna(), yticklabels=False, cbar=True,  cmap='viridis')

# %% [markdown]
# Vấn đề 5:

# %%
patientheartrate = patientheartrate.drop_duplicates(subset=['Firstname','Lastname', 'Age', 'Weight'])
patientheartrate
# Out:
#       ID   Age Weight m0006 m0612 m1218 f006 f0612 f1218 Firstname Lastname
# 0    1.0  56.0  70kgs    72    69    71    -     -     -    Mickéy    Mousé
# 1    2.0  34.0  70kgs     -     -     -   85    84    76    Donald     Duck
# 2    3.0  16.0    NaN     -     -     -   65    69    72      Mini    Mouse
# 3    4.0   NaN  78kgs    78    79    72    -     -     -   Scrooge   McDuck
# 4    5.0  54.0  90kgs     -     -     -   69   NaN    75      Pink  Panther
# 5    6.0  52.0  85kgs     -     -     -   68    75    72      Huey   McDuck
# 6    7.0  19.0  56kgs     -     -     -   71    78    75     Dewey   McDuck
# 7    8.0  32.0  78kgs    78    76    75    -     -     -    Scööpy      Doo
# 11  10.0  12.0  45kgs     -     -     -   92    95    87     Louie   McDuck
# 12  11.0   NaN  60kgs    78    75    72    -     -     -     Henry      Nam
# 13  12.0  34.0    NaN    65    67    55    -     -     -    Michel     Long
# 14  13.0   NaN    NaN     -     -     -   68    72    70      Tana    Ricky
# 15  14.0   NaN    NaN   NaN   NaN   NaN  NaN   NaN   NaN  UniLever     None
# 16  15.0  52.0  81kgs     -     -     -   68    75    72       NaN      NaN

# %% [markdown]
# Vấn đề 6:

# %%
patientheartrate.Firstname.replace({r'[^\x00-\x7F]+':''}, regex=True,inplace=True)
patientheartrate.Lastname.replace({r'[^\x00-\x7F]+':''}, regex=True,inplace=True)

patientheartrate
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
#       ID   Age Weight m0006 m0612 m1218 f006 f0612 f1218 Firstname Lastname
# 0    1.0  56.0  70kgs    72    69    71    -     -     -     Micky     Mous
# 1    2.0  34.0  70kgs     -     -     -   85    84    76    Donald     Duck
# 2    3.0  16.0    NaN     -     -     -   65    69    72      Mini    Mouse
# 3    4.0   NaN  78kgs    78    79    72    -     -     -   Scrooge   McDuck
# 4    5.0  54.0  90kgs     -     -     -   69   NaN    75      Pink  Panther
# 5    6.0  52.0  85kgs     -     -     -   68    75    72      Huey   McDuck
# 6    7.0  19.0  56kgs     -     -     -   71    78    75     Dewey   McDuck
# 7    8.0  32.0  78kgs    78    76    75    -     -     -      Scpy      Doo
# 11  10.0  12.0  45kgs     -     -     -   92    95    87     Louie   McDuck
# 12  11.0   NaN  60kgs    78    75    72    -     -     -     Henry      Nam
# 13  12.0  34.0    NaN    65    67    55    -     -     -    Michel     Long
# 14  13.0   NaN    NaN     -     -     -   68    72    70      Tana    Ricky
# 15  14.0   NaN    NaN   NaN   NaN   NaN  NaN   NaN   NaN  UniLever     None
# 16  15.0  52.0  81kgs     -     -     -   68    75    72       NaN      NaN

# %% [markdown]
# Vấn đề 7

# %%
sns.heatmap(patientheartrate.isna(), yticklabels=False, cbar=True, cmap='viridis')

# %%
index_ageweightnull = patientheartrate[patientheartrate['Age'].isna() & patientheartrate['Weight'].isna()].index
index_ageweightnull
# Out:
# Int64Index([14, 15], dtype='int64')

# %%
patientheartrate.drop(index_ageweightnull, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
patientheartrate['Age'].fillna(patientheartrate['Age'].mean(), inplace =False)
# Out:
# 0     56.0
# 1     34.0
# 2     16.0
# 3     36.1
# 4     54.0
# 5     52.0
# 6     19.0
# 7     32.0
# 11    12.0
# 12    36.1
# 13    34.0
# 16    52.0
# Name: Age, dtype: float64

# %% [markdown]
# Vấn đề 8

# %%
patientheartrate
# Out:
#       ID   Age Weight m0006 m0612 m1218 f006 f0612 f1218 Firstname Lastname
# 0    1.0  56.0  70kgs    72    69    71    -     -     -     Micky     Mous
# 1    2.0  34.0  70kgs     -     -     -   85    84    76    Donald     Duck
# 2    3.0  16.0    NaN     -     -     -   65    69    72      Mini    Mouse
# 3    4.0   NaN  78kgs    78    79    72    -     -     -   Scrooge   McDuck
# 4    5.0  54.0  90kgs     -     -     -   69   NaN    75      Pink  Panther
# 5    6.0  52.0  85kgs     -     -     -   68    75    72      Huey   McDuck
# 6    7.0  19.0  56kgs     -     -     -   71    78    75     Dewey   McDuck
# 7    8.0  32.0  78kgs    78    76    75    -     -     -      Scpy      Doo
# 11  10.0  12.0  45kgs     -     -     -   92    95    87     Louie   McDuck
# 12  11.0   NaN  60kgs    78    75    72    -     -     -     Henry      Nam
# 13  12.0  34.0    NaN    65    67    55    -     -     -    Michel     Long
# 16  15.0  52.0  81kgs     -     -     -   68    75    72       NaN      NaN

# %%
df = pd.melt(patientheartrate, id_vars=['ID', 'Age', 'Weight', 'Firstname', 'Lastname'], value_name="PulseRate",var_name="sex_and_time").sort_values(['ID', 'Age', 'Weight', 'Firstname', 'Lastname'])
df
# Out:
#       ID   Age Weight Firstname Lastname sex_and_time PulseRate
# 0    1.0  56.0  70kgs     Micky     Mous        m0006        72
# 12   1.0  56.0  70kgs     Micky     Mous        m0612        69
# 24   1.0  56.0  70kgs     Micky     Mous        m1218        71
# 36   1.0  56.0  70kgs     Micky     Mous         f006         -
# 48   1.0  56.0  70kgs     Micky     Mous        f0612         -
# ..   ...   ...    ...       ...      ...          ...       ...
# 23  15.0  52.0  81kgs       NaN      NaN        m0612         -
# 35  15.0  52.0  81kgs       NaN      NaN        m1218         -
# 47  15.0  52.0  81kgs       NaN      NaN         f006        68
# 59  15.0  52.0  81kgs       NaN      NaN        f0612        75
# 71  15.0  52.0  81kgs       NaN      NaN        f1218        72
#
# [72 rows x 7 columns]

# %%
len(df['PulseRate'])
# Out:
# 72

# %%
df.head(10)
# Out:
#      ID   Age Weight Firstname Lastname sex_and_time PulseRate
# 0   1.0  56.0  70kgs     Micky     Mous        m0006        72
# 12  1.0  56.0  70kgs     Micky     Mous        m0612        69
# 24  1.0  56.0  70kgs     Micky     Mous        m1218        71
# 36  1.0  56.0  70kgs     Micky     Mous         f006         -
# 48  1.0  56.0  70kgs     Micky     Mous        f0612         -
# 60  1.0  56.0  70kgs     Micky     Mous        f1218         -
# 1   2.0  34.0  70kgs    Donald     Duck        m0006         -
# 13  2.0  34.0  70kgs    Donald     Duck        m0612         -
# 25  2.0  34.0  70kgs    Donald     Duck        m1218         -
# 37  2.0  34.0  70kgs    Donald     Duck         f006        85

# %%
#Extract sex, hour lower bound and hour upper dound group
tmp_df= df["sex_and_time"].str.extract("(\D)(\d+)(\d{2})", expand=True)

# %%
#Name columns
tmp_df.columns=["Sex","hours_lower","hours_upper"]

# %%
#Create Time column based on "hours_lower" and "hours_upper" columns
tmp_df["Time"]=tmp_df["hours_lower"] + "-"+ tmp_df["hours_upper"]

# %%
#Merge
df =pd.concat([df, tmp_df], axis=1)

# %%
#Drop unnecessary columns and rows
df = df.drop(['sex_and_time','hours_lower','hours_upper'], axis=1)
df = df.dropna()

# %%
len(df['PulseRate'])
# Out:
# 41

# %%
df.head(10)
# Out:
#      ID   Age Weight Firstname Lastname PulseRate  0   1   2 Sex   Time
# 0   1.0  56.0  70kgs     Micky     Mous        72  m  00  06   m  00-06
# 12  1.0  56.0  70kgs     Micky     Mous        69  m  06  12   m  06-12
# 24  1.0  56.0  70kgs     Micky     Mous        71  m  12  18   m  12-18
# 36  1.0  56.0  70kgs     Micky     Mous         -  f   0  06   f   0-06
# 48  1.0  56.0  70kgs     Micky     Mous         -  f  06  12   f  06-12
# 60  1.0  56.0  70kgs     Micky     Mous         -  f  12  18   f  12-18
# 1   2.0  34.0  70kgs    Donald     Duck         -  m  00  06   m  00-06
# 13  2.0  34.0  70kgs    Donald     Duck         -  m  06  12   m  06-12
# 25  2.0  34.0  70kgs    Donald     Duck         -  m  12  18   m  12-18
# 37  2.0  34.0  70kgs    Donald     Duck        85  f   0  06   f   0-06

# %%
sns.heatmap(df.isna(), yticklabels=False, cbar=True, cmap='viridis')

# %%
df['PulseRate']= df['PulseRate'].replace({'-' : '0'}, regex=True)
df["PulseRate"].fillna('0', inplace =True)
len(df["PulseRate"])
df["PulseRate"]
# Out:
# 0     72
# 12    69
# 24    71
# 36     0
# 48     0
# 60     0
# 1      0
# 13     0
# 25     0
# 37    85
# 49    84
# 61    76
# 4      0
# 16     0
# 28     0
# 40    69
# 64    75
# 5      0
# 17     0
# 29     0
# 41    68
# 53    75
# 65    72
# 6      0
# 18     0
# 30     0
# 42    71
# 54    78
# 66    75
# 7     78
# 19    76
# 31    75
# 43     0
# 55     0
# 67     0
# 8      0
# 20     0
# 32     0
# 44    92
# 56    95
# 68    87
# Name: PulseRate, dtype: object

# %%
def avgPulserate(df, firstname):
  sumPulserate = 0
  nsumPulserate = 0
  for i, value in enumerate(df['Firstname']):
    if value == firstname:
      try:
        if df['PulseRate'][i] !='0':
          sumPulserate += int(df['PulseRate'].values[i])
          nsumPulserate += 1
      except:
        pass
  if nsumPulserate > 0:
    return str(sumPulserate/nsumPulserate)
  else:
    return 0

def isValidIndex1(index, nrows):
  return index - 1 > 0 & index + 1 < nrows

def isValidIndex2(index, nrows):
  return index + 1 < nrows & index + 2 < nrows

def isPulseRateNotNull1(index, df):
  return str(df['PulseRate'].values[index-1])!= '0' and str(df['PulseRate'].values[index+1])!= '0'

def isPulseRateNotNull2(index, df):
  return str(df['PulseRate'].values[index+1])!= '0' and str(df['PulseRate'].values[index +2])!= '0'

def isInGroup1(df, index, firstname):
  return df['Firstname'].values[index-1]== firstname and df['Firstname'].values[index +1]== firstname

def isInGroup2(df, index, firstname):
  return df['Firstname'].values[index+1]== firstname and df['Firstname'].values[index +2]== firstname

def updatePulseRatena (index, df):
  nrows = len(df['PulseRate']) -2
  newvalue = ''
  firstname = df['Firstname'].values[index]
  try:
    if isValidIndex1(index,nrows) & isPulseRateNotNull1(index, df) & isInGroup1(df, index, firstname):
      try: 
        newvalue = (int(df['PulseRate'].values[index-1]) + int(df['PulseRate'].values[index+1]))/2
      except:
        newvalue = '0'
    elif isValidIndex2(index,nrows) & isPulseRateNotNull2(index, df) & isInGroup2(df, index, firstname):
      try:
        newvalue = (int(df['PulseRate'].values[index-1]) + int(df['PulseRate'].values[index+1]))/2
      except:
        newvalue ='0'
    else:
      newvalue = avgPulserate(df, firstname)
  except:
      newvalue = avgPulserate(df, firstname)
  finally:
    pass
  return newvalue

# %%
pulserateupdate = []
for index, value in enumerate(df["PulseRate"]):
  if value =='0' or value == '':
    newvalue = updatePulseRatena(index,df)
    pulserateupdate.append(newvalue)
  else:
    pulserateupdate.append(value)

# %%
df["PulseRateUpdate"] = pulserateupdate

# %%
len(df["PulseRateUpdate"])
# Out:
# 41

# %%
df.head(10)
# Out:
#      ID   Age Weight Firstname Lastname  ...   1   2 Sex   Time PulseRateUpdate
# 0   1.0  56.0  70kgs     Micky     Mous  ...  00  06   m  00-06              72
# 12  1.0  56.0  70kgs     Micky     Mous  ...  06  12   m  06-12              69
# 24  1.0  56.0  70kgs     Micky     Mous  ...  12  18   m  12-18              71
# 36  1.0  56.0  70kgs     Micky     Mous  ...   0  06   f   0-06            72.0
# 48  1.0  56.0  70kgs     Micky     Mous  ...  06  12   f  06-12            72.0
# 60  1.0  56.0  70kgs     Micky     Mous  ...  12  18   f  12-18            72.0
# 1   2.0  34.0  70kgs    Donald     Duck  ...  00  06   m  00-06             0.0
# 13  2.0  34.0  70kgs    Donald     Duck  ...  06  12   m  06-12             0.0
# 25  2.0  34.0  70kgs    Donald     Duck  ...  12  18   m  12-18             0.0
# 37  2.0  34.0  70kgs    Donald     Duck  ...   0  06   f   0-06              85
#
# [10 rows x 12 columns]

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#       ID   Age Weight Firstname Lastname  ...   1   2 Sex   Time PulseRateUpdate
# 0    1.0  56.0  70kgs     Micky     Mous  ...  00  06   m  00-06              72
# 1    2.0  34.0  70kgs    Donald     Duck  ...  00  06   m  00-06             0.0
# 4    5.0  54.0  90kgs      Pink  Panther  ...  00  06   m  00-06             0.0
# 5    6.0  52.0  85kgs      Huey   McDuck  ...  00  06   m  00-06             0.0
# 6    7.0  19.0  56kgs     Dewey   McDuck  ...  00  06   m  00-06             0.0
# 7    8.0  32.0  78kgs      Scpy      Doo  ...  00  06   m  00-06              78
# 8   10.0  12.0  45kgs     Louie   McDuck  ...  00  06   m  00-06            43.5
# 12   1.0  56.0  70kgs     Micky     Mous  ...  06  12   m  06-12              69
# 13   2.0  34.0  70kgs    Donald     Duck  ...  06  12   m  06-12             0.0
# 16   5.0  54.0  90kgs      Pink  Panther  ...  06  12   m  06-12             0.0
# 17   6.0  52.0  85kgs      Huey   McDuck  ...  06  12   m  06-12             0.0
# 18   7.0  19.0  56kgs     Dewey   McDuck  ...  06  12   m  06-12             0.0
# 19   8.0  32.0  78kgs      Scpy      Doo  ...  06  12   m  06-12              76
# 20  10.0  12.0  45kgs     Louie   McDuck  ...  06  12   m  06-12            43.5
# 24   1.0  56.0  70kgs     Micky     Mous  ...  12  18   m  12-18              71
# 25   2.0  34.0  70kgs    Donald     Duck  ...  12  18   m  12-18             0.0
# 28   5.0  54.0  90kgs      Pink  Panther  ...  12  18   m  12-18             0.0
# 29   6.0  52.0  85kgs      Huey   McDuck  ...  12  18   m  12-18             0.0
# 30   7.0  19.0  56kgs     Dewey   McDuck  ...  12  18   m  12-18             0.0
# 31   8.0  32.0  78kgs      Scpy      Doo  ...  12  18   m  12-18              75
# 32  10.0  12.0  45kgs     Louie   McDuck  ...  12  18   m  12-18            43.5
# 36   1.0  56.0  70kgs     Micky     Mous  ...   0  06   f   0-06            72.0
# 37   2.0  34.0  70kgs    Donald     Duck  ...   0  06   f   0-06              85
# 40   5.0  54.0  90kgs      Pink  Panther  ...   0  06   f   0-06              69
# 41   6.0  52.0  85kgs      Huey   McDuck  ...   0  06   f   0-06              68
# 42   7.0  19.0  56kgs     Dewey   McDuck  ...   0  06   f   0-06              71
# 43   8.0  32.0  78kgs      Scpy      Doo  ...   0  06   f   0-06            75.0
# 44  10.0  12.0  45kgs     Louie   McDuck  ...   0  06   f   0-06              92
# 48   1.0  56.0  70kgs     Micky     Mous  ...  06  12   f  06-12            72.0
# 49   2.0  34.0  70kgs    Donald     Duck  ...  06  12   f  06-12              84
# 53   6.0  52.0  85kgs      Huey   McDuck  ...  06  12   f  06-12              75
# 54   7.0  19.0  56kgs     Dewey   McDuck  ...  06  12   f  06-12              78
# 55   8.0  32.0  78kgs      Scpy      Doo  ...  06  12   f  06-12            75.0
# 56  10.0  12.0  45kgs     Louie   McDuck  ...  06  12   f  06-12              95
# 60   1.0  56.0  70kgs     Micky     Mous  ...  12  18   f  12-18            72.0
# 61   2.0  34.0  70kgs    Donald     Duck  ...  12  18   f  12-18              76
# 64   5.0  54.0  90kgs      Pink  Panther  ...  12  18   f  12-18              75
# 65   6.0  52.0  85kgs      Huey   McDuck  ...  12  18   f  12-18              72
# 66   7.0  19.0  56kgs     Dewey   McDuck  ...  12  18   f  12-18              75
# 67   8.0  32.0  78kgs      Scpy      Doo  ...  12  18   f  12-18            75.0
# 68  10.0  12.0  45kgs     Louie   McDuck  ...  12  18   f  12-18              87
#
# [41 rows x 12 columns]

# %%
df.to_csv('patient_heart_rate_clean.csv')
